# %% [markdown]
# # Yolov8
#
# [Yolov8🚀](https://github.com/ultralytics/ultralytics)

# %%
import ultralytics
import torch


device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
print(device)

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.13 torch-2.2.0 CUDA:0 (NVIDIA A100 80GB PCIe, 81051MiB)
# Setup complete ✅ (96 CPUs, 866.1 GB RAM, 989.8/1984.7 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('/home/KDT-admin/work/ssm/yolov8/runs/detect/train21/weights/best.pt')  
model.val(data='/home/KDT-admin/work/ssm/yolov8/emotion4000.yaml')
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.13 torch-2.2.0 CUDA:0 (NVIDIA A100 80GB PCIe, 81051MiB)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/KDT-admin/work/data6_yolo_1000_300_640/validation/labels.cache... 2100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2100/2100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 132/132 [00:19<00:00,  6.77it/s]
#                    all       2100       2100      0.651      0.703       0.72      0.662
#                  anger       2100        300      0.648      0.733      0.767        0.7
#                 normal       2100        300      0.781      0.833      0.874      0.807
#                  happy       2100        300      0.923      0.963      0.968      0.894
#              embarrass       2100        300      0.642      0.713      0.733      0.676
# ...

# %%
# from ultralytics import YOLO

# model = YOLO('/home/KDT-admin/work/ssm/yolov8/runs/detect/train22/weights/best.pt')  # load a pretrained YOLOv8n detection model
# # img = '/home/KDT-admin/work/data3/test/anger/df62cbb8881ee439441fe4d67a7ce2440f2349559ecbf5fbf0d700ae2b10ff60_남_20_분노_실외 자연환경_20210202085037-007-010.jpg'
# data = '/home/KDT-admin/work/data3/test/normal'
# results = model.predict(data, save_crop=True)
# Out:
# image 1/1000 /home/KDT-admin/work/data3/test/normal/df62cbb8881ee439441fe4d67a7ce2440f2349559ecbf5fbf0d700ae2b10ff60_남_20_중립_도심 환경_20210202084753-008-006.jpg: 480x640 1 normal, 11.5ms
# image 2/1000 /home/KDT-admin/work/data3/test/normal/df62cbb8881ee439441fe4d67a7ce2440f2349559ecbf5fbf0d700ae2b10ff60_남_20_중립_상업시설&점포&시장_20210202084724-003-006.jpg: 480x640 1 normal, 10.9ms
# image 3/1000 /home/KDT-admin/work/data3/test/normal/df62cbb8881ee439441fe4d67a7ce2440f2349559ecbf5fbf0d700ae2b10ff60_남_20_중립_숙박 및 거주공간_20210202084805-010-003.jpg: 480x640 1 normal, 1 anxiety, 10.4ms
# image 4/1000 /home/KDT-admin/work/data3/test/normal/df62cbb8881ee439441fe4d67a7ce2440f2349559ecbf5fbf0d700ae2b10ff60_남_20_중립_숙박 및 거주공간_20210202084805-010-006.jpg: 480x640 1 normal, 17.1ms
# image 5/1000 /home/KDT-admin/work/data3/test/normal/dfc02b14400e9fcaec446cf4eeee7d7131a714d579c59ce60883423caec73cdf_여_20_중립_공공시설&종교&의료시설_20201207134633-001-001.jpg: 480x640 1 normal, 25.9ms
# ...
